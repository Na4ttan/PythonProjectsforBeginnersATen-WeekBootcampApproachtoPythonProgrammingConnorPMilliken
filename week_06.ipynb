# %% [markdown]
# # Dictionaries

# %%
# Monday:

# %%
# declaring a dictionary variable
empty = {} #empty dictionary
person = {"name ": "John Smith"}
    #dictionary with one key/value pair
customer = {
    "name": "Morty",
    "age": 26
}    #dictionary with two key/values pairs
print(customer)
# Out:
# {'name': 'Morty', 'age': 26}

# %%
#accessing dictionary information throgh keys
person = {"name": "John"}
print(person["name"])    # access information thrugh the
# Out:
# John

# %%
# using the get  to acess dictionary information
person = {
    "name": "John"
}
print(person.get("name")) # retrieves value of name keys as before
print(person.get("age", "Age is not available.")) #get is a secure way to retrieve information
# Out:
# John
# Age is not available.

# %%
# storing a list within a dictionary and acessing it
data = {
    "sports":["baseball", "football", "hockey", "soccer"]
}
print(data["sports"][0]) #first access the key, then the index
# Out:
# baseball

# %%
# improperly storing a list within a dictionary
sports = ["baseball", "football", "hockey", "soccer"]
sport_dict = dict(sports) # Will produce error, no key
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # improperly storing a list within a dictionary
#       2 sports = ["baseball", "football", "hockey", "soccer"]
# ----> 3 sport_dict = dict(sports)
#
# ValueError: dictionary update sequence element #0 has length 8; 2 is required

# %%
meu_dict = dict(nome="Alice", idade=25, cidade="São Paulo")
# Resultado: {'nome': 'Alice', 'idade': 25, 'cidade': 'São Paulo'}

# %%
lista_pares = [("cor", "azul"), ("tamanho", "G")]
meu_dict = dict(lista_pares)
# Resultado: {'cor': 'azul', 'tamanho': 'G'}

# %%
chaves = ['id', 'status', 'prioridade']
valores = [101, 'ativo', 'alta']
meu_dict = dict(zip(chaves, valores))
# Resultado: {'id': 101, 'status': 'ativo', 'prioridade': 'alta'}

# %%
# storing a dictionary within a list and accessing it
data = ["John", "Dennis", {"name":"Kirsten"}]
print(data[2]) #the dictionary is in index 2
print(data[2]["name"]) # first access the index, then access the key
# Out:
# {'name': 'Kirsten'}
# Kirsten

# %%
# storing a dictionary within a dictionary and accessing it
data = {
    "team" : "Boston Red Sox",
    "wins": {"2018" : 108, "2017" : 93}
}
print(data["wins"]) #will output the dictionary within the wins key
print(data["wins"]["2018"]) # first access the wins key, then the next key
# Out:
# {'2018': 108, '2017': 93}
# 108

# %%
#week 6
#monday exercises 
namein = input("What's your name?")
agein = input("how old are you?")

dados = dict(name = namein, age = agein)
print(dados)
# Out:
# What's your name? Natan
# how old are you? 33
# {'name': 'Natan', 'age': '33'}

# %%
#week 6
#monday exercises 
pizza = {
    'ingredients' : ['cheese', 'sausage', 'peppers']
}
list = []
for i in pizza['ingredients']:
    list.append(i)
print(list)
# Out:
# ['cheese', 'sausage', 'peppers']

# %%
# Tuesday:

# %%
# adding new key-value pairs to a dictionary 
car = {
    "year" : 2018
}
car["color"] = "Blue"
print("Year: {} \t Color: {}".format(car["year"], car["color"]))
# Out:
# Year: 2018 	 Color: Blue

# %%
# updating a value for a key/value pair that already exists
car = {
    "year" : 2018,
    "car" : "Blue"
}
car["color"] = "Red"
print("Year: {} \t Color: {}".format(car["year"], car["color"]))
# Out:
# Year: 2018 	 Color: Red

# %%
# deleting a key/value pair from a dictionary
car = {
    "year" : 2028
}
try:
    del car["year"]
    print(car)
except:
    print("That key does not exist")
# Out:
# {}

# %%
# looping over a dictionary via the keys
person = {
    "name" : "John",
    "age" : 26
}
for key in person.keys():
    print(key)
    print(person[key]) # will output the value at the current key
# Out:
# name
# John
# age
# 26

# %%
# looping over a dictionary via the values
person = {
    "name" : "John",
    "age" : 26
}
for value in person.values():
    print(value)
# Out:
# John
# 26

# %%
# Tuesday Exercises
person = {}
name = input("Whats your name? ")
address = input("Whats your addres? ")
number = input("Whats your phone number? ")
person["name"] = name
person["address"] = address
person["number"] = number

for key in person.keys():
    print(key)
    print(person[key])
# Out:
# Whats your name?  Natan
# Whats your addres?  rua 1
# Whats your phone number?  11999995555
# name
# Natan
# address
# rua 1
# number
# 11999995555

# %%
# Tuesday Exercises
person = {"name","John"} # o erro é a vírtgula no lugar dos dois pontos
print(person["name"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Tuesday Exercises
#       2 person = {"name","John"} # o erro é a vírtgula no lugar dos dois pontos
# ----> 3 print(person["name"])
#
# TypeError: 'set' object is not subscriptable

# %%
# Tuesday Exercises
person = {"name":"John"} # o erro é a vírtgula no lugar dos dois pontos
print(person["name"])
# Out:
# John

# %%
# declaring a tuple
t1 = ("Hello", 2, "Hello") # with parens
t2 = True, 1 # without parens
print(type(t1), type(t2)) #both are tuples
t1[0] = 1 # will crash, tuples are immutable once declared
# Out:
# <class 'tuple'> <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 t2 = True, 1 # without parens
#       4 print(type(t1), type(t2)) #both are tuples
# ----> 5 t1[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
# declaring a set
s1 = set([1, 2, 3, 1]) # uses the set keyword and square brackets
s2 = {4, 4, 5} # uses curly brackets, like dictionary
print(type(s1), type(s2))
s1.add(5) 
s1.remove(1) # using the remove method to get rid of the value 1
print(s1)
# Out:
# <class 'set'> <class 'set'>
# {2, 3, 5}

# %%
'''
Em Python, sets são uma estrutura de dados que representa um conjunto — exatamente como na matemática.
Características principais:
- Não permitem elementos duplicados (cada item aparece apenas uma vez).
- Não possuem ordem fixa (não são indexados como listas).
- São mutáveis (podem ser modificados), mas seus elementos precisam ser imutáveis (por exemplo, números, strings, tuplas).
- São muito úteis para operações de teoria dos conjuntos, como união, interseção e diferença.

'''
# Out:
# '\nEm Python, sets são uma estrutura de dados que representa um conjunto — exatamente como na matemática.\nCaracterísticas principais:\n- Não permitem elementos duplicados (cada item aparece apenas uma vez).\n- Não possuem ordem fixa (não são indexados como listas).\n- São mutáveis (podem ser modificados), mas seus elementos precisam ser imutáveis (por exemplo, números, strings, tuplas).\n- São muito úteis para operações de teoria dos conjuntos, como união, interseção e diferença.\n\n'

# %%
# Criando um set
frutas = {"maçã", "banana", "laranja"}

# Adicionando um elemento
frutas.add("uva")

# Removendo um elemento
frutas.remove("banana")

# Operações de conjuntos
A = {1, 2, 3}
B = {3, 4, 5}

print(A | B)  # União → {1, 2, 3, 4, 5}
print(A & B)  # Interseção → {3}
print(A - B)  # Diferença → {1, 2}
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %%
# declaring a frozenset
fset = frozenset([1, 2, 3, 4])
print(type(fset))
# Out:
# <class 'frozenset'>

# %%
 '''
 O que são frozensets?
Um frozenset em Python é uma versão imutável de um conjunto (set).
- Enquanto um set pode ser alterado (adicionar, remover elementos), um frozenset não permite modificações depois de criado.
- Por ser imutável, ele pode ser usado como chave em dicionários ou armazenado dentro de outros conjuntos — algo que não é possível com set.
 Características principais:
- Não permite elementos duplicados (como o set).
- Não possui ordem fixa.
- É imutável: não aceita operações como .add() ou .remove().
- Suporta operações de conjuntos: união, interseção, diferença, etc.
'''
# Out:
# '\nO que são frozensets?\nUm frozenset em Python é uma versão imutável de um conjunto (set).\n- Enquanto um set pode ser alterado (adicionar, remover elementos), um frozenset não permite modificações depois de criado.\n- Por ser imutável, ele pode ser usado como chave em dicionários ou armazenado dentro de outros conjuntos — algo que não é possível com set.\nCaracterísticas principais:\n- Não permite elementos duplicados (como o set).\n- Não possui ordem fixa.\n- É imutável: não aceita operações como .add() ou .remove().\n- Suporta operações de conjuntos: união, interseção, diferença, etc.\n'

# %%
# Criando um frozenset
A = frozenset([1, 2, 3, 4])
B = frozenset([3, 4, 5, 6])

# Operações de conjuntos
print(A | B)  # União → frozenset({1, 2, 3, 4, 5, 6})
print(A & B)  # Interseção → frozenset({3, 4})
print(A - B)  # Diferença → frozenset({1, 2})
# Out:
# frozenset({1, 2, 3, 4, 5, 6})
# frozenset({3, 4})
# frozenset({1, 2})

# %%
#wednesday exercise
numbers = []

while True:
    number = int(input("insert a number account or zero to finish: "))
    if number == 0:
        break
    else:
        numbers.append(number)

accounts = frozenset(numbers)
print(accounts)
# Out:
# insert a number account or zero to finish:  32323232
# insert a number account or zero to finish:  43434343
# insert a number account or zero to finish:  12121212
# insert a number account or zero to finish:  66556655
# insert a number account or zero to finish:  0
# frozenset({32323232, 66556655, 12121212, 43434343})

# %%
#wednesday exercise
nums = [3, 4, 3, 7, 10]
snums = set(nums)
print(snums)
# Out:
# {10, 3, 4, 7}

# %%
#Thursday: Reading and Whiting Files

# %%
# opening/creating and writing to a text file
f = open("test.txt", "w+") # open file in writing and reading mode
f.write("this is a test")
f.close()
# reading from a text file
f = open("test.txt", "r")
data = f.read()
f.close()
print(data)
# Out:
# this is a test

# %%
# opening/creating and writing a csv file
import csv
with open("test.csv", mode="w", newline="") as f:
    writer = csv.writer(f, delimiter=",")
    writer.writerow(["Name", "City"])
    writer.writerow(["Craig Lou", "Taiwan"])

# %%
# reading from csv files
with open("test.csv", mode="r") as f:
    reader = csv.reader(f, delimiter=",")
    for row in reader:
        print(row)
# Out:
# ['Name', 'City']
# ['Craig Lou', 'Taiwan']

# %%
print(type(reader))
# Out:
# <class '_csv.reader'>

# %%
# Thursday Exercises

# %%
#User input: Ask a user for their favorite number, and save it to a text file
favoriteNumber = int(input("Whats your favorite number? "))
f = open("favnumber.txt", "w+")
f.write("The favorite number is {}".format(favoriteNumber))
f.close()
# reading from a text file favnumber
f = open("favnumber.txt", "r")
data = f.read()
f.close()
print(data)
# Out:
# Whats your favorite number?  10
# The favorite number is 10

# %%
# Thursday Exercises
# Data  Dumping: Using the dictionary of following data, save the information to csv file with keys as the headers and the values as the rows of data
import csv
data = {
    'name' : ["Dave", "Dennis", "Peter", "Jess"],
    'language' : ["Python", "C", "Java", "Python"]
}
name = data["name"]
language = data["language"]

with open("dataDumping.csv", mode="w", newline="") as f:
    writer = csv.writer(f, delimiter=",")
    writer.writerow(data.keys())
    for linha in range(len(name)):
        writer.writerow([name[linha], language[linha]])

# %%
# forma mais limpa e pythonica

# %%
import csv

data = {
    'name': ["Dave", "Dennis", "Peter", "Jess"],
    'language': ["Python", "C", "Java", "Python"]
}

with open("dataDumping.csv", mode="w", newline="") as f:
    writer = csv.writer(f)
    
    # Escreve o cabeçalho usando as chaves diretamente
    writer.writerow(data.keys())
    
    # O zip() percorre os valores das listas simultaneamente
    # Descompactamos as listas de dentro do dicionário direto no loop
    for n, l in zip(data['name'], data['language']):
        writer.writerow([n, l])

# %%
# Friday Project: Creating a user Database with CSV Files.

# %%
# import all necessary packages to be used
import csv
from IPython.display import clear_output

# variables for main loop
active = True
logged_in = False
emailglobal = ""
passglobal = ""

# handle user registration and writing to csv
def registerUser():
    with open("user.csv", mode="a", newline="") as f:
        writer = csv.writer(f, delimiter=",")
        print("To register, please inter your info: ")
        email = input("E-mail: ")
        password = input("Password: ")
        password2 = input("Re-type password: ")
        clear_output()
        if password == password2:
            writer.writerow([email, password])
            print("You are now registered!")
        else:
            print('Something went wrong. Try again.')

# ask for a user info and return true to loggin or false if incorrect info
def logginUser():
    global emailglobal, passglobal # Importante para o status persistir
    print("To login, please enter your info: ")
    email = input("E-mail: ")
    password = input("Password: ")
    clear_output()
    
    try:
        with open("user.csv", mode="r") as f:
            reader = csv.reader(f, delimiter=",")
            for row in reader:
                # row é uma lista como ['email@teste.com', '123']
                if row == [email, password]:
                    emailglobal = email
                    passglobal = password
                    print("You are logged in!")
                    return True
    except FileNotFoundError:
        print("No user database found. Please register first.")
        return False

    print("Something went wrong, try again.")
    return False

# ... (outras funções)

#weekly challenges
# Changing Passwords:
def changePassword():
    global emailglobal, passglobal
    with open("user.csv", mode="w", newline="") as f:
        writer = csv.writer(f, delimiter=",")
        print("To change your password, please enter your info: ")
        password = input("Password: ")
        password2 = input("Re-type password: ")
        clear_output()
        if password == password2:
            reader = csv.reader(f, delimiter=",")
            for row in reader:
                if row in reader:
                    del reader[row]
                    writer.writerow([emailglobal, passglobal])
                    print("The password were changed!")
        else:
            print("Something went wrong, try again.")

# main loop
while active:
    if logged_in:
        print("1. Logout\n2. Changepassword\n3. Quit")
    else:
        print("1. Login\n2. Register\n3. Quit")
    choice = input("What would you like to do? ").lower()
    clear_output()
    if choice == "register" and logged_in == False:
        registerUser()
    elif choice == "login" and logged_in == False:
        logged_in = logginUser()
    elif choice == "quit":
        active = False
        print("Thanks for using our software!")
    elif choice == "logout" and logged_in == True:
        logged_in = False
        print("You are now logged out.")
    elif choice == "changepassword" and logged_in == True:
        changePassword()
    else:
        print("Sorry, please try again!")
# Out:
# Thanks for using our software!

# %%
#Continuar no WEEKLY CHALLENGES
