# %% [markdown]
# # Week 07

# %% [markdown]
# # Creating and Instantiating a Class

# %%
# creating our first class
class car():
    pass # simply using as a placeholder until we add more code tomorrow
ford = car()
print(ford)

# %%
# instantiating multiple objects from the same class
class car():
    pass
ford = car()
subaru = car() # creating another object from the car class
print(hash(ford))
print(hash(subaru)) #hash outputs a numerical representation of the location in memory for the variable
# Out:
# 122059401959
# 122059389683

# %%
# Monday Exercises

# %%
class animal():
    breed = ""
    color = ""
    age = int
    
lion = animal()
tiger = animal()
tiger.age = 4

print(tiger.age)
# Out:
# 4

# %% [markdown]
# # Tuesday - Attributes

# %%
# how to define a class attribute
class car():
    sound = "beep"
    color = "red"
ford = car()
print(ford.color)
# Out:
# red

# %%
# changing the value of an atribute
class car():
    sound = "beep"
    color = "red"
ford = car()
print(ford.sound)
ford.sound = "honk"
print(ford.sound)
# Out:
# beep
# honk

# %%
# using the init method to give instances personalized attributes upon creation
class Car():
    def __init__(self, color):
        self.color = color # sets the attribute color to the value passed in

ford = car("blue") # instantiating a Car class with the color blue
print(ford.color)
# Out:
# blue

# %%
# definig different values for multiple instances
class Car():
    def __init__(self, color, year):
        self.color = color # sets the attribute color to the value passed in
        self.year = year

ford = Car("blue", 2026) # creating a car object with the color blue and year 2026
subaru = Car("red", 2018) # creating a car object with the color red and year 2018

print(ford.color, ford.year)
print(subaru.color, subaru.year)
# Out:
# blue 2026
# red 2018

# %%
# Using and accessing global class attributes
class Car():
    sound = "beep" # global attribute, accessible through the class itself
    def __init__(self, color):
        self.color = "blue" # instance specific attribute, not accessible through the class itself
print(Car.sound)
# print(Car.color) wont work, as color is only available to instances of the car class, not the class itself

ford = Car("blue")
print(ford.sound, ford.color)

# teste
ford.sound = "bibi!!"
ford.color = "green"
print(ford.sound, ford.color)
# Out:
# beep
# beep blue
# bibi!! green

# %%
# Tuesday exercises
class Dog():
    species = "Canine"
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed
sammi = Dog("Sammi", "Husky")
casey = Dog("Casey", "Chocolate Lab")

print(sammi.species, sammi.name, sammi.breed)
print(casey.species, casey.name, casey.breed)
# Out:
# Canine Sammi Husky
# Canine Casey Chocolate Lab

# %%
# Tuesday exercises
class Person():
    def __init__(self, name):
        self.name = name
studant = Person(input("What's your name? "))
print(studant.name)
# Out:
# What's your name?  Natan
# Natan

# %% [markdown]
# # Wednesday - Methods

# %%
# defining and calling our first class method
class Dog():
    def makeSound(self):
        print("bark")
sam = Dog()
sam.makeSound()
# Out:
# bark

# %%
# understanding which methods are accessible via the class  itself and class instances
class Dog():
    sound = "bark"
    def makeSound(self):
        print(self.sound)
    def printInfo():
        print("I am a dog.")
Dog.printInfo() # able to run printInfo method because it does not include self parameter

sam = Dog()
sam.makeSound() # able to access, self can references the instance of sam
# Sam.printInfo() will produce a error, instances require the self parameter to access methods
# Out:
# I am a dog.
# bark

# %%
# writing methods that accept parameters
class Dog():
    def showAge(self, age):
        print(age) # does not need self, age is  referencing the parameter not an attribute
sam = Dog()
sam.showAge(6)
# Out:
# 6

# %%
# using methods to set or return attribute values, proper programming practice
class Dog():
    name = "" # would normally use init method to declare, this is for testing purposes
    def setName(self, new_name):
        self.name = new_name # declares the new value for the name attribute
    def getName(self):
        return self.name
sam = Dog()
sam.setName("Sammi")
print(sam.getName())
# Out:
# Sammi

# %%
# inclementing/decrementing attribute values with methods, best programming practice
class Dog():
    age = 5
    def happyBirthday(self):
        self.age += 1
sam = Dog()
sam.happyBirthday()
print(sam.age) # better practice use getters
# Out:
# 6

# %%
# calling a class method from another method
class Dog():
    age = 6
    def getAge(self):
        return self.age
    def printInfo(self):
        if self.getAge() < 10: # need self to call other method for an instance
            print("Puppy")
sam = Dog()
sam.printInfo()
# Out:
# Puppy

# %%
# using magic methods
class Dog():
    def __str__(self):
        return "This is a dog class"
sam = Dog()
print(sam) # will print the return of the string magic method
# Out:
# This is a dog class

# %%
# Wednesday Exercises

# %%
class Animal():
    species = ""
    def setSpecies(self, newSpecies):
        self.species = newSpecies
    def getSpecies(self):
        return self.species
lion = Animal()
lion.setSpecies("feline")
print(lion.getSpecies())
print(animal.species) # a class não recebeu o valor, só a instancia
# Out:
# feline

# %%
class Person():
    name = input("What's your name? ")
    age = 0
    def setAge(self):
        self.age = input("Whats your age? ")
    def getAge(self):
        return self.age
user = Person()
user.setAge()
print(user.getAge())
# Out:
# What's your name?  Natan
# Whats your age?  33
# 33

# %% [markdown]
# # Thursday: Inheritance

# %%
# inheriting a class and accessing the inherited method
class Animal():
    def makeSound(self):
        print("roar")
class Dog(Animal): # inheriting Animal class
    species = "Canine"
sam = Dog()
sam.makeSound() # accessible through inheritance
lion = Animal()
# lion.species not accessible, inheritance does not work backwards
# Out:
# roar

# %%
# using the super() method to declare inherited attributes
class Animal():
    def __init__(self, species):
        self.species = species
class Dog(Animal):
    def __init__(self, species, name):
        self.name = name
        super().__init__(species) # using super to declare the species attribute defined in Animal
sam = Dog("Canine", "Sammi")
print(sam.species)
# Out:
# Canine

# %%
# overriding methods defined in the superclass
class Animal():
    def makeSound(self):
        print("roar")
class Dog(Animal):
    def makeSound(self):
        print("bark")
sam, lion = Dog(), Animal()
sam.makeSound()
lion.makeSound()
# Out:
# bark
# roar

# %%
# how to inherit multiple class
class Physics():
    gravity = 9.8
class Automobile():
    def __init__(self, make, model, year):
        self.make, self.model, self.year = make, model, year # declaaring all attributes on one line
class Ford(Physics, Automobile):
    def __init__(self, model, year):
        Automobile.__init__(self, "Ford", model, year) # super does not work with multiple # - Isso significa: “pegue o método __init__ da classe Automobile e execute-o, passando este objeto (self) como primeiro argumento, junto com os valores "Ford", model e year”.
truck = Ford("F-150", 2018)
print(truck.gravity, truck.make) # output both attributes

#testando formas de exibir os atributos
print(truck.__dict__)
print(vars(truck))
#print(dir(truck))
# Out:
# 9.8 Ford
# {'make': 'Ford', 'model': 'F-150', 'year': 2018}
# {'make': 'Ford', 'model': 'F-150', 'year': 2018}

# %%
# Exercises

# %%
class Characters():
    def __init__(self, name, team, height, weight):
        if team == "good" or "bad":
            self.name, self.team, self.height, self.weight = name, team, height, weight
    def sayHello(self, name, team):
        if team == "good":
            print("Hello, my name is {} and I'm on the good guys".format(self.name))
        elif team == "bad":
            print("Hello, my name is {} and I'm on the bad guys".format(self.name))

class GoodPlayers(Characters):
    def __init__(self, name, team, height, weight):
        super().__init__(name, team, height, weight)
        super().sayHello(name, team)
class BadPlayers(Characters):
    def __init__(self, name, team, height, weight):
        super().__init__(name, team, height, weight)
        super().sayHello(name, team)
        
themax = GoodPlayers("Max", "good", 1.83, 80)
thetony = BadPlayers("Tony", "bad", 1.80, 75)
# Out:
# Hello, my name is Max and I'm on the good guys
# Hello, my name is Tony and I'm on the bad guys

# %%
#refatorado
class Characters():
    def __init__(self, name, team, height, weight):
        if team == "good" or team == "bad":
            self.name, self.team, self.height, self.weight = name, team, height, weight
    def sayHello(self):
        if self.team == "good":
            print("Hello, my name is {} and I'm on the good guys".format(self.name))
        elif self.team == "bad":
            print("Hello, my name is {} and I'm on the bad guys".format(self.name))
    def __str__(self):
    return f"Personagem: {self.name} | Time: {self.team} | Altura: {self.height}m"

class GoodPlayers(Characters):
    def __init__(self, name, team, height, weight):
        super().__init__(name, team, height, weight)

class BadPlayers(Characters):
    def __init__(self, name, team, height, weight):
        super().__init__(name, team, height, weight)
        
themax = GoodPlayers("Max", "good", 1.83, 80)
thetony = BadPlayers("Tony", "bad", 1.80, 75)

themax.sayHello()
thetony.sayHello()
print(themax)
# Out:
#   Cell In[14], line 12
#     return f"Personagem: {self.name} | Time: {self.team} | Altura: {self.height}m"
#     ^
# IndentationError: expected an indented block after function definition on line 11

# %% [markdown]
# # Friday Project: Creating Blackjack

# %%
# importing necessary functions
from random import randint # allows us to get a random number
from IPython.display import clear_output
